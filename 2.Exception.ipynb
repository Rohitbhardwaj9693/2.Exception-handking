# %%
# Explain why we have to use the Exception class while creating a custom 
# Exception



# Because when we use exception class while creating custom exceptiion 
# when we use exception class. inherite all exception handle in a class

# %%
# write a python program to print python exception herarchy
# import inspect module 
import inspect 
# our treeclass function 
def treeclass(cls, ind = 0):
    
    #print name of the clss
    print ('_' * ind ,cls.__name__)
    
    # iterating through subclass
    for i in cls.__subclasses__():
        treeclass(i,ind +3)
print('hericary for built in exception is :')


# inspect.getmro() return a tuple 
# of class cls base classes
# building a tree herarchy

inspect.getclasstree(inspect.getmro(BaseException))
#function call
treeclass(BaseException)
# Out:
# hericary for built in exception is :
#  BaseException
# ___ Exception
# ______ TypeError
# _________ FloatOperation
# _________ MultipartConversionError
# ______ StopAsyncIteration
# ______ StopIteration
# ______ ImportError
# _________ ModuleNotFoundError
# _________ ZipImportError
# ______ OSError
# _________ ConnectionError
# ____________ BrokenPipeError
# ____________ ConnectionAbortedError
# ____________ ConnectionRefusedError
# ____________ ConnectionResetError
# _______________ RemoteDisconnected
# _________ BlockingIOError
# _________ ChildProcessError
# _________ FileExistsError
# _________ FileNotFoundError
# _________ IsADirectoryError
# _________ NotADirectoryError
# _________ InterruptedError
# ____________ InterruptedSystemCall
# _________ PermissionError
# _________ ProcessLookupError
# _________ TimeoutError
# _________ UnsupportedOperation
# _________ itimer_error
# _________ herror
# _________ gaierror
# _________ SSLError
# ____________ SSLCertVerificationError
# ...

# %%
# What error are define in the ArithmeticError class? Explain any two with 
# an example
# The arithmetic error occur when an error is encountered during numeric 
# calculating in python .
# 1.ZerodevisionError
# 2.Floating point error

try:
    x,y = 10,0
    div = x/y
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
# Why lookupError class is used? Explain with an example keyError and IndexError

# The lookupError exception in python froms the base class for all exception 
# that are raised when an index or a key is not found for a sequence or 
# dictionary respectively .you can lookupError exception class to handle both
# IndexError and KeyError exception class

try:
    l = [1,2,3,4,5]
    print(l[7])
except IndexError as e:
    print(e)
try:
    d = {'key':'Rohit','key1':'Rishi'}
    print(d['key2'])
except KeyError as e:
    print(e)
# Out:
# list index out of range
# 'key2'

# %%
# Explain ImportError .What is moduleNotFoundError

# in python , ImportError occurs when the python program tries to import moduke 
# which dose not exit in private table .this exception can be avoid using 
# exception can be avoid using exception handling using try and except block


# The module not found error is a syntex errior that appear when the stati
# import statement cannot find the file at the declear path .this common
# syntex error is caused by letter- casing inconsistiance that are preaent in
# your filename (s ) between your repository and local machine or both

# %%
# list down some best practise for exception handling in python

# 1.Explicit is better than implicit
# 2.Flat is better than nested
# 3.write custom exception
# 4.Keep your try/except block narrow
# 5.Actually use them
# 7.verbose logging
